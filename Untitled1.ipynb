# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('churn.csv.xls')

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 1          1   83807.86              1          0               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 4          2  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 0           101348.88       1
# 1           112542.58       0
# 2           113931.57       1
# 3            93826.63       0
# 4            79084.10       0
# ...               ...     ...
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0
#
# [10000 rows x 14 columns]

# %%
features = df.drop(columns=['Exited'],axis=1)
features
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 1          1   83807.86              1          0               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 4          2  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary
# 0           101348.88
# 1           112542.58
# 2           113931.57
# 3            93826.63
# 4            79084.10
# ...               ...
# 9995         96270.64
# 9996        101699.77
# 9997         42085.58
# 9998         92888.52
# 9999         38190.78
#
# [10000 rows x 13 columns]

# %%
target = df['Exited']
target
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 9995    0
# 9996    0
# 9997    1
# 9998    1
# 9999    0
# Name: Exited, Length: 10000, dtype: int64

# %%
features = features.dropna()
features
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 1          1   83807.86              1          0               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 4          2  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary
# 0           101348.88
# 1           112542.58
# 2           113931.57
# 3            93826.63
# 4            79084.10
# ...               ...
# 9995         96270.64
# 9996        101699.77
# 9997         42085.58
# 9998         92888.52
# 9999         38190.78
#
# [10000 rows x 13 columns]

# %%
features = features.drop(columns=['RowNumber','CustomerId','Surname'],axis=1)
features
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France  Female   42       2       0.00              1
# 1             608     Spain  Female   41       1   83807.86              1
# 2             502    France  Female   42       8  159660.80              3
# 3             699    France  Female   39       1       0.00              2
# 4             850     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary
# 0             1               1        101348.88
# 1             0               1        112542.58
# 2             1               0        113931.57
# 3             0               0         93826.63
# 4             1               1         79084.10
# ...         ...             ...              ...
# 9995          1               0         96270.64
# 9996          1               1        101699.77
# 9997          0               1         42085.58
# 9998          1               0         92888.52
# 9999          1               0         38190.78
#
# [10000 rows x 10 columns]

# %%
features = pd.get_dummies(features,columns=['Geography','Gender'])

# %%
features
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Geography_France  Geography_Germany  \
# 0                  1        101348.88              True              False
# 1                  1        112542.58             False              False
# 2                  0        113931.57              True              False
# 3                  0         93826.63              True              False
# 4                  1         79084.10             False              False
# ...              ...              ...               ...                ...
# 9995               0         96270.64              True              False
# 9996               1        101699.77              True              False
# 9997               1         42085.58              True              False
# 9998               0         92888.52             False               True
# 9999               0         38190.78              True              False
#
#       Geography_Spain  Gender_Female  Gender_Male
# 0               False           True        False
# 1                True           True        False
# 2               False           True        False
# 3               False           True        False
# 4                True           True        False
# ...               ...            ...          ...
# 9995            False          False         True
# 9996            False          False         True
# 9997            False           True        False
# 9998            False          False         True
# 9999            False           True        False
#
# [10000 rows x 13 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
X_train, X_test, y_train,y_test = train_test_split(features, target, test_size = 0.2, random_state = 42)

# %%
X_train
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 9254          686   32       6       0.00              2          1
# 1561          632   42       4  119624.60              2          1
# 1670          559   24       3  114739.92              1          1
# 6087          561   27       9  135637.00              1          1
# 6669          517   56       9  142147.32              1          0
# ...           ...  ...     ...        ...            ...        ...
# 5734          768   54       8   69712.74              1          1
# 5191          682   58       1       0.00              1          1
# 5390          735   38       1       0.00              3          0
# 860           667   43       8  190227.46              1          1
# 7270          697   51       1  147910.30              1          1
#
#       IsActiveMember  EstimatedSalary  Geography_France  Geography_Germany  \
# 9254               1        179093.26              True              False
# 1561               1        195978.86             False               True
# 1670               0         85891.02             False              False
# 6087               0        153080.40              True              False
# 6669               0         39488.04              True              False
# ...              ...              ...               ...                ...
# 5734               1         69381.05              True              False
# 5191               1           706.50              True              False
# 5390               0         92220.12              True              False
# 860                0         97508.04              True              False
# 7270               1         53581.14             False               True
#
#       Geography_Spain  Gender_Female  Gender_Male
# 9254            False          False         True
# 1561            False          False         True
# 1670             True          False         True
# 6087            False           True        False
# 6669            False          False         True
# ...               ...            ...          ...
# 5734            False          False         True
# 5191            False           True        False
# 5390            False           True        False
# 860             False          False         True
# 7270            False          False         True
#
# [8000 rows x 13 columns]

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_train
# Out:
# array([[ 0.35649971, -0.6557859 ,  0.34567966, ..., -0.57638802,
#         -0.91324755,  0.91324755],
#        [-0.20389777,  0.29493847, -0.3483691 , ..., -0.57638802,
#         -0.91324755,  0.91324755],
#        [-0.96147213, -1.41636539, -0.69539349, ...,  1.73494238,
#         -0.91324755,  0.91324755],
#        ...,
#        [ 0.86500853, -0.08535128, -1.38944225, ..., -0.57638802,
#          1.09499335, -1.09499335],
#        [ 0.15932282,  0.3900109 ,  1.03972843, ..., -0.57638802,
#         -0.91324755,  0.91324755],
#        [ 0.47065475,  1.15059039, -1.38944225, ..., -0.57638802,
#         -0.91324755,  0.91324755]])

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import pickle

import xgboost as xgb
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier

# %%
lr_model = LogisticRegression(random_state=42)

# %%
lr_model.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=42)

# %%
lr_predictions = lr_model.predict(X_test)

# %%
lr_predictions
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
lr_accuracy = accuracy_score(y_test, lr_predictions)
lr_accuracy
# Out:
# 0.811

# %%
def evaluate_and_save_model(model, X_train, X_test, y_train, y_test, filename):
    model.fit(X_train, y_train)
    prediction = model.predict(X_test)
    accuracy = accuracy_score(y_test, prediction)
    print(f"{model.__class__.__name__} Accuracy: {accuracy}")
    print(f"\n Classification Report: \n{classification_report(y_test, prediction)}")
    print("--------------")

    with open(filename, 'wb') as file:
      pickle.dump(model, file)

# %%
xgb_model = xgb.XGBClassifier(random_state=42)
evaluate_and_save_model(xgb_model, X_train, X_test, y_train, y_test, "xgb_model.pkl")

dt_model = DecisionTreeClassifier(random_state=42)
evaluate_and_save_model(dt_model, X_train, X_test, y_train, y_test, "dt_model.pkl")

rf_model = RandomForestClassifier(random_state=42)
evaluate_and_save_model(rf_model, X_train, X_test, y_train, y_test, "rf_model.pkl")

nb_model = GaussianNB()
evaluate_and_save_model(nb_model, X_train, X_test, y_train, y_test, "nb_model.pkl")

knn_model = KNeighborsClassifier()
evaluate_and_save_model(knn_model, X_train, X_test, y_train, y_test, "knn_model.pkl")

svm_model = SVC(random_state=42)
evaluate_and_save_model(svm_model, X_train, X_test, y_train, y_test, "svm_model.pkl")
# Out:
# XGBClassifier Accuracy: 0.8625
#
#  Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.89      0.95      0.92      1607
#            1       0.71      0.51      0.59       393
#
#     accuracy                           0.86      2000
#    macro avg       0.80      0.73      0.76      2000
# weighted avg       0.85      0.86      0.85      2000
#
# --------------
# DecisionTreeClassifier Accuracy: 0.7805
#
#  Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.85      0.86      1607
#            1       0.45      0.51      0.48       393
#
#     accuracy                           0.78      2000
#    macro avg       0.66      0.68      0.67      2000
# weighted avg       0.79      0.78      0.79      2000
#
# --------------
# RandomForestClassifier Accuracy: 0.8635
#
#  Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.96      0.92      1607
#            1       0.75      0.46      0.57       393
#
#     accuracy                           0.86      2000
#    macro avg       0.81      0.71      0.75      2000
# weighted avg       0.85      0.86      0.85      2000
#
# --------------
# GaussianNB Accuracy: 0.82
#
#  Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.86      0.93      0.89      1607
#            1       0.56      0.38      0.45       393
#
#     accuracy                           0.82      2000
#    macro avg       0.71      0.65      0.67      2000
# weighted avg       0.80      0.82      0.81      2000
#
# --------------
# KNeighborsClassifier Accuracy: 0.829
#
#  Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.86      0.94      0.90      1607
#            1       0.61      0.37      0.46       393
#
#     accuracy                           0.83      2000
#    macro avg       0.73      0.65      0.68      2000
# weighted avg       0.81      0.83      0.81      2000
#
# --------------
# SVC Accuracy: 0.8545
#
#  Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.86      0.97      0.91      1607
#            1       0.76      0.38      0.50       393
#
#     accuracy                           0.85      2000
#    macro avg       0.81      0.67      0.71      2000
# weighted avg       0.84      0.85      0.83      2000
#
# --------------

# %%
feature_importances = xgb_model.feature_importances_
feature_names = features.columns

# %%
feature_importances
# Out:
# array([0.03500515, 0.10955004, 0.03005428, 0.05278617, 0.32388842,
#        0.03194036, 0.16414644, 0.03265523, 0.04646328, 0.09137332,
#        0.0368547 , 0.04528258, 0.        ], dtype=float32)

# %%
feature_importances_df = pd.DataFrame({
    'Feature': feature_names,
    'Importance': feature_importances
})
feature_importances_df
# Out:
#               Feature  Importance
# 0         CreditScore    0.035005
# 1                 Age    0.109550
# 2              Tenure    0.030054
# 3             Balance    0.052786
# 4       NumOfProducts    0.323888
# 5           HasCrCard    0.031940
# 6      IsActiveMember    0.164146
# 7     EstimatedSalary    0.032655
# 8    Geography_France    0.046463
# 9   Geography_Germany    0.091373
# 10    Geography_Spain    0.036855
# 11      Gender_Female    0.045283
# 12        Gender_Male    0.000000

# %%
feature_importances_df = feature_importances_df.sort_values('Importance',ascending=False)

# %%
feature_importances_df
# Out:
#               Feature  Importance
# 4       NumOfProducts    0.323888
# 6      IsActiveMember    0.164146
# 1                 Age    0.109550
# 9   Geography_Germany    0.091373
# 3             Balance    0.052786
# 8    Geography_France    0.046463
# 11      Gender_Female    0.045283
# 10    Geography_Spain    0.036855
# 0         CreditScore    0.035005
# 7     EstimatedSalary    0.032655
# 5           HasCrCard    0.031940
# 2              Tenure    0.030054
# 12        Gender_Male    0.000000

# %%
sns.barplot(x="Feature",y="Importance",data=feature_importances_df)
# Out:
# <Axes: xlabel='Feature', ylabel='Importance'>

# %%
plt.figure(figsize=(10,6))
plt.bar(feature_importances_df['Feature'],feature_importances_df['Importance'])
plt.xticks(rotation=90)
plt.xlabel('Features')
plt.ylabel('Importance')
plt.tight_layout()
plt.show()

# %%
features['CLV'] = df['Balance'] * df['EstimatedSalary'] / 100000
features
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Geography_France  Geography_Germany  \
# 0                  1        101348.88              True              False
# 1                  1        112542.58             False              False
# 2                  0        113931.57              True              False
# 3                  0         93826.63              True              False
# 4                  1         79084.10             False              False
# ...              ...              ...               ...                ...
# 9995               0         96270.64              True              False
# 9996               1        101699.77              True              False
# 9997               1         42085.58              True              False
# 9998               0         92888.52             False               True
# 9999               0         38190.78              True              False
#
#       Geography_Spain  Gender_Female  Gender_Male            CLV
# 0               False           True        False       0.000000
# 1                True           True        False   94319.527887
# 2               False           True        False  181904.056115
# 3               False           True        False       0.000000
# 4                True           True        False   99259.102400
# ...               ...            ...          ...            ...
# 9995            False          False         True       0.000000
# 9996            False          False         True   58344.761420
# 9997            False           True        False       0.000000
# 9998            False          False         True   69736.344344
# 9999            False           True        False   49702.546615
#
# [10000 rows x 14 columns]

# %%
features['AgeGroup'] = pd.cut(df['Age'],bins=[0,30,45,60,100],labels=['Young','Middle Age','Senior','Elderly'])
features
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Geography_France  Geography_Germany  \
# 0                  1        101348.88              True              False
# 1                  1        112542.58             False              False
# 2                  0        113931.57              True              False
# 3                  0         93826.63              True              False
# 4                  1         79084.10             False              False
# ...              ...              ...               ...                ...
# 9995               0         96270.64              True              False
# 9996               1        101699.77              True              False
# 9997               1         42085.58              True              False
# 9998               0         92888.52             False               True
# 9999               0         38190.78              True              False
#
#       Geography_Spain  Gender_Female  Gender_Male            CLV    AgeGroup
# 0               False           True        False       0.000000  Middle Age
# 1                True           True        False   94319.527887  Middle Age
# 2               False           True        False  181904.056115  Middle Age
# 3               False           True        False       0.000000  Middle Age
# 4                True           True        False   99259.102400  Middle Age
# ...               ...            ...          ...            ...         ...
# 9995            False          False         True       0.000000  Middle Age
# 9996            False          False         True   58344.761420  Middle Age
# 9997            False           True        False       0.000000  Middle Age
# 9998            False          False         True   69736.344344  Middle Age
# 9999            False           True        False   49702.546615       Young
#
# [10000 rows x 15 columns]

# %%
features
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Geography_France  Geography_Germany  \
# 0                  1        101348.88              True              False
# 1                  1        112542.58             False              False
# 2                  0        113931.57              True              False
# 3                  0         93826.63              True              False
# 4                  1         79084.10             False              False
# ...              ...              ...               ...                ...
# 9995               0         96270.64              True              False
# 9996               1        101699.77              True              False
# 9997               1         42085.58              True              False
# 9998               0         92888.52             False               True
# 9999               0         38190.78              True              False
#
#       Geography_Spain  Gender_Female  Gender_Male            CLV    AgeGroup
# 0               False           True        False       0.000000  Middle Age
# 1                True           True        False   94319.527887  Middle Age
# 2               False           True        False  181904.056115  Middle Age
# 3               False           True        False       0.000000  Middle Age
# 4                True           True        False   99259.102400  Middle Age
# ...               ...            ...          ...            ...         ...
# 9995            False          False         True       0.000000  Middle Age
# 9996            False          False         True   58344.761420  Middle Age
# 9997            False           True        False       0.000000  Middle Age
# 9998            False          False         True   69736.344344  Middle Age
# 9999            False           True        False   49702.546615       Young
#
# [10000 rows x 15 columns]

# %%
features['TenureAgeRatio'] = df['Tenure']/df['Age']
features
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Geography_France  Geography_Germany  \
# 0                  1        101348.88              True              False
# 1                  1        112542.58             False              False
# 2                  0        113931.57              True              False
# 3                  0         93826.63              True              False
# 4                  1         79084.10             False              False
# ...              ...              ...               ...                ...
# 9995               0         96270.64              True              False
# 9996               1        101699.77              True              False
# 9997               1         42085.58              True              False
# 9998               0         92888.52             False               True
# 9999               0         38190.78              True              False
#
#       Geography_Spain  Gender_Female  Gender_Male            CLV    AgeGroup  \
# 0               False           True        False       0.000000  Middle Age
# 1                True           True        False   94319.527887  Middle Age
# 2               False           True        False  181904.056115  Middle Age
# 3               False           True        False       0.000000  Middle Age
# 4                True           True        False   99259.102400  Middle Age
# ...               ...            ...          ...            ...         ...
# 9995            False          False         True       0.000000  Middle Age
# 9996            False          False         True   58344.761420  Middle Age
# 9997            False           True        False       0.000000  Middle Age
# 9998            False          False         True   69736.344344  Middle Age
# 9999            False           True        False   49702.546615       Young
#
#       TenureAgeRatio
# 0           0.047619
# 1           0.024390
# 2           0.190476
# 3           0.025641
# 4           0.046512
# ...              ...
# 9995        0.128205
# 9996        0.285714
# 9997        0.194444
# 9998        0.071429
# 9999        0.142857
#
# [10000 rows x 16 columns]

# %%
features = pd.get_dummies(features,drop_first=True)
features
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Geography_France  Geography_Germany  \
# 0                  1        101348.88              True              False
# 1                  1        112542.58             False              False
# 2                  0        113931.57              True              False
# 3                  0         93826.63              True              False
# 4                  1         79084.10             False              False
# ...              ...              ...               ...                ...
# 9995               0         96270.64              True              False
# 9996               1        101699.77              True              False
# 9997               1         42085.58              True              False
# 9998               0         92888.52             False               True
# 9999               0         38190.78              True              False
#
#       Geography_Spain  Gender_Female  Gender_Male            CLV  \
# 0               False           True        False       0.000000
# 1                True           True        False   94319.527887
# 2               False           True        False  181904.056115
# 3               False           True        False       0.000000
# 4                True           True        False   99259.102400
# ...               ...            ...          ...            ...
# 9995            False          False         True       0.000000
# 9996            False          False         True   58344.761420
# 9997            False           True        False       0.000000
# 9998            False          False         True   69736.344344
# 9999            False           True        False   49702.546615
#
#       TenureAgeRatio  AgeGroup_Middle Age  AgeGroup_Senior  AgeGroup_Elderly
# 0           0.047619                 True            False             False
# 1           0.024390                 True            False             False
# 2           0.190476                 True            False             False
# 3           0.025641                 True            False             False
# 4           0.046512                 True            False             False
# ...              ...                  ...              ...               ...
# 9995        0.128205                 True            False             False
# 9996        0.285714                 True            False             False
# 9997        0.194444                 True            False             False
# 9998        0.071429                 True            False             False
# 9999        0.142857                False            False             False
#
# [10000 rows x 18 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# %%
X_train
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 9254          686   32       6       0.00              2          1
# 1561          632   42       4  119624.60              2          1
# 1670          559   24       3  114739.92              1          1
# 6087          561   27       9  135637.00              1          1
# 6669          517   56       9  142147.32              1          0
# ...           ...  ...     ...        ...            ...        ...
# 5734          768   54       8   69712.74              1          1
# 5191          682   58       1       0.00              1          1
# 5390          735   38       1       0.00              3          0
# 860           667   43       8  190227.46              1          1
# 7270          697   51       1  147910.30              1          1
#
#       IsActiveMember  EstimatedSalary  Geography_France  Geography_Germany  \
# 9254               1        179093.26              True              False
# 1561               1        195978.86             False               True
# 1670               0         85891.02             False              False
# 6087               0        153080.40              True              False
# 6669               0         39488.04              True              False
# ...              ...              ...               ...                ...
# 5734               1         69381.05              True              False
# 5191               1           706.50              True              False
# 5390               0         92220.12              True              False
# 860                0         97508.04              True              False
# 7270               1         53581.14             False               True
#
#       Geography_Spain  Gender_Female  Gender_Male            CLV  \
# 9254            False          False         True       0.000000
# 1561            False          False         True  234438.927360
# 1670             True          False         True   98551.287635
# 6087            False           True        False  207633.662148
# 6669            False          False         True   56131.190581
# ...               ...            ...          ...            ...
# 5734            False          False         True   48367.430996
# 5191            False           True        False       0.000000
# 5390            False           True        False       0.000000
# 860             False          False         True  185487.067788
# 7270            False          False         True   79252.024917
#
#       TenureAgeRatio  AgeGroup_Middle Age  AgeGroup_Senior  AgeGroup_Elderly
# 9254        0.187500                 True            False             False
# 1561        0.095238                 True            False             False
# 1670        0.125000                False            False             False
# 6087        0.333333                False            False             False
# 6669        0.160714                False             True             False
# ...              ...                  ...              ...               ...
# 5734        0.148148                False             True             False
# 5191        0.017241                False             True             False
# 5390        0.026316                 True            False             False
# 860         0.186047                 True            False             False
# 7270        0.019608                False             True             False
#
# [8000 rows x 18 columns]

# %%
xgboost_model = xgb.XGBClassifier(random_state=42)
evaluate_and_save_model(xgboost_model, X_train, X_test, y_train, y_test, "xgboost_enhanced.pkl")
# Out:
# XGBClassifier Accuracy: 0.854
#
#  Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.89      0.94      0.91      1607
#            1       0.67      0.50      0.58       393
#
#     accuracy                           0.85      2000
#    macro avg       0.78      0.72      0.74      2000
# weighted avg       0.84      0.85      0.85      2000
#
# --------------

# %%
from imblearn.over_sampling import SMOTE

# %%
smote = SMOTE(random_state=42)

# %%
X_resampled, Y_resampled = smote.fit_resample(X_train, y_train)

# %%
X_resampled
# Out:
#        CreditScore  Age  Tenure        Balance  NumOfProducts  HasCrCard  \
# 0              686   32       6       0.000000              2          1
# 1              632   42       4  119624.600000              2          1
# 2              559   24       3  114739.920000              1          1
# 3              561   27       9  135637.000000              1          1
# 4              517   56       9  142147.320000              1          0
# ...            ...  ...     ...            ...            ...        ...
# 12707          680   45       6  138664.343105              1          0
# 12708          730   43       8       0.000000              1          0
# 12709          769   32       2       0.000000              1          1
# 12710          678   46       8  107135.399805              1          0
# 12711          682   33       7  135933.455251              2          1
#
#        IsActiveMember  EstimatedSalary  Geography_France  Geography_Germany  \
# 0                   1    179093.260000              True              False
# 1                   1    195978.860000             False               True
# 2                   0     85891.020000             False              False
# 3                   0    153080.400000              True              False
# 4                   0     39488.040000              True              False
# ...               ...              ...               ...                ...
# 12707               1      1669.789623              True               True
# 12708               0    199220.081437             False              False
# 12709               0    193872.703755              True              False
# 12710               0    137130.699174             False               True
# 12711               0    102336.825532              True               True
#
#        Geography_Spain  Gender_Female  Gender_Male            CLV  \
# 0                False          False         True       0.000000
# 1                False          False         True  234438.927360
# 2                 True          False         True   98551.287635
# 3                False           True        False  207633.662148
# 4                False          False         True   56131.190581
# ...                ...            ...          ...            ...
# 12707            False           True         True    2294.475108
# 12708             True           True         True       0.000000
# 12709             True           True         True       0.000000
# 12710            False           True        False  146910.454113
# 12711            False           True         True  139124.245526
#
#        TenureAgeRatio  AgeGroup_Middle Age  AgeGroup_Senior  AgeGroup_Elderly
# 0            0.187500                 True            False             False
# 1            0.095238                 True            False             False
# 2            0.125000                False            False             False
# 3            0.333333                False            False             False
# 4            0.160714                False             True             False
# ...               ...                  ...              ...               ...
# 12707        0.139889                 True             True             False
# 12708        0.201548                 True            False             False
# 12709        0.067343                 True            False             False
# 12710        0.194402                 True             True             False
# 12711        0.232298                 True            False             False
#
# [12712 rows x 18 columns]

# %%
Y_resampled
# Out:
# 0        0
# 1        0
# 2        1
# 3        1
# 4        1
#         ..
# 12707    1
# 12708    1
# 12709    1
# 12710    1
# 12711    1
# Name: Exited, Length: 12712, dtype: int64

# %%
evaluate_and_save_model(xgboost_model, X_resampled, X_test, Y_resampled, y_test, "xgboost_SMOTE.pkl")
# Out:
# XGBClassifier Accuracy: 0.8545
#
#  Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.89      0.93      0.91      1607
#            1       0.65      0.55      0.60       393
#
#     accuracy                           0.85      2000
#    macro avg       0.77      0.74      0.75      2000
# weighted avg       0.85      0.85      0.85      2000
#
# --------------

# %%
from sklearn.ensemble import VotingClassifier

# %%
voting_classifier = VotingClassifier(estimators=[('xgboost',xgb.XGBClassifier(random_state=42)),('rf', RandomForestClassifier(random_state=42)),('svm',SVC(random_state=42, probability=True))],
                                     voting='hard')

# %%
evaluate_and_save_model(voting_classifier, X_resampled, X_test, Y_resampled, y_test, "voting_clf.pkl")
# Out:
# VotingClassifier Accuracy: 0.853
#
#  Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.90      0.92      0.91      1607
#            1       0.63      0.59      0.61       393
#
#     accuracy                           0.85      2000
#    macro avg       0.77      0.75      0.76      2000
# weighted avg       0.85      0.85      0.85      2000
#
# --------------
